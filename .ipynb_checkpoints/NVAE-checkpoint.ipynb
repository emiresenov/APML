# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

import torch
from torchvision import datasets, transforms

# use GPU for computation if possible
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# load code for NVAE

# make sure that files in local directory can be imported
import sys
sys.path.insert(0, ".")

# try to import nvae module and download it if it fails
import urllib
try:
    import nvae
except ImportError:
    urllib.request.urlretrieve("https://uu-sml.github.io/course-apml-public/lab/nvae.py", "nvae.py")
    import nvae

# %% [markdown]
# # Deep hierarchical variational autoencoder
#
# We studied PCA, probabilistic PCA, and a simple variational autoencoder (VAE) on the MNIST data of handwritten digits in exercise 11.1 and the computer lab (links to the material can be found [here](https://uu-sml.github.io/course-apml-public/)). In this notebook we will play around with a much more complicated VAE, the so-called [nouveau variational autoencoder (NVAE)](https://arxiv.org/abs/2007.03898). It is based on an advanced deep hierarchical structure of the encoder and decoder. The authors applied it to multiple image data sets such as the MNIST data set and the [CelebA](https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) and [CelebA HQ](https://research.nvidia.com/sites/default/files/pubs/2017-10_Progressive-Growing-of/karras2018iclr-paper.pdf) data sets of celebrity images. The image below shows samples of the NVAE for the CelebA HQ data set.
#
# <img src="https://raw.githubusercontent.com/NVlabs/NVAE/master/img/celebahq.png" width="800">

# %% [markdown]
# ## Before you start
#
# It is strongly recommended that you complete the first parts of the computer lab and perform a probabilistic PCA and train a simple VAE on the MNIST data before running this notebook. You can download the notebook for the PPCA model [here](https://uu-sml.github.io/course-apml-public/lab/PPCA.ipynb) and run it on your computer, or you can [open it on Google Colab](https://colab.research.google.com/github/uu-sml/course-apml-public/blob/master/lab/PPCA.ipynb). The notebook for the VAE you can download [here](https://uu-sml.github.io/course-apml-public/lab/VAE.ipynb) or you can [open it on Google Colab](https://colab.research.google.com/github/uu-sml/course-apml-public/blob/master/lab/VAE.ipynb)
#
# We recommend also that you [open this notebook on Google Colab](https://colab.research.google.com/github/uu-sml/course-apml-public/blob/master/lab/NVAE.ipynb) since it allows you to use GPUs which will speed up the computations a lot (you can enable GPU support in the "Runtime" -> "Change runtime type" menu). Alternatively, you can run the notebook on your computer. In this notebook we use [PyTorch](https://pytorch.org/), an open source software library for machine learning. Make sure that you have installed the latest version of PyTorch if you run the notebook on your computer.
#
# A Jupyter notebook with an introduction to PyTorch can be downloaded from [here](https://uu-sml.github.io/course-sml-public/lab/introduction.ipynb). Alternatively, you can [open it on Google Colab](https://colab.research.google.com/github/uu-sml/course-sml-public/blob/master/lab/introduction.ipynb). Reading and running the notebook is highly recommended, since it introduces important concepts and commands that are required in this notebook.

# %% [markdown]
# ## Model
#
# The NVAE model is too large to be trained on your computer (or on Google Colab) during the lab session. Therefore we use pretrained parameters that are [made available by the authors](https://github.com/NVlabs/NVAE#post-training-sampling-evaluation-and-checkpoints). We download the parameters (the filesize is around 217MB) and construct a NVAE for the MNIST data.

# %%
# load pretrained NVAE for MNIST
model = nvae.load_pretrained_model("mnist")

# move model to the GPU if available
model = model.to(device)
# Out:
# downloading checkpoint of pretrained model for mnist ...
# len log norm: 183
# len bn: 128

# %% [markdown]
# We can print a summary of the network architecture.

# %%
model
# Out:
# AutoEncoder(
#   (stem): Conv2D(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pre_process): ModuleList(
#     (0-1): 2 x Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(32, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): Cell(
#       (skip): FactorizedReduce(
#         (conv_1): Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         (conv_2): Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         (conv_3): Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#         (conv_4): Conv2D(32, 16, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (_ops): ModuleList(
#         (0): BNSwishConv(
#           (bn_act): BatchNorm2d(32, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): BNSwishConv(
#           (bn_act): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3-4): 2 x Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): Cell(
#       (skip): FactorizedReduce(
#         (conv_1): Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         (conv_2): Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         (conv_3): Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#         (conv_4): Conv2D(64, 32, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (_ops): ModuleList(
#         (0): BNSwishConv(
#           (bn_act): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (enc_tower): ModuleList(
#     (0): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (2): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (5): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (6): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (7): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (8): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (9): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (10): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (11): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (13): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (14): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (15): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (16): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (17): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (18): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (19): EncCombinerCell(
#       (conv): Conv2D(128, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (20): Cell(
#       (skip): FactorizedReduce(
#         (conv_1): Conv2D(128, 64, kernel_size=(1, 1), stride=(2, 2))
#         (conv_2): Conv2D(128, 64, kernel_size=(1, 1), stride=(2, 2))
#         (conv_3): Conv2D(128, 64, kernel_size=(1, 1), stride=(2, 2))
#         (conv_4): Conv2D(128, 64, kernel_size=(1, 1), stride=(2, 2))
#       )
#       (_ops): ModuleList(
#         (0): BNSwishConv(
#           (bn_act): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         )
#         (1): BNSwishConv(
#           (bn_act): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (21): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (22): EncCombinerCell(
#       (conv): Conv2D(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (23): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (24): EncCombinerCell(
#       (conv): Conv2D(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (25): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (26): EncCombinerCell(
#       (conv): Conv2D(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (27): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (28): EncCombinerCell(
#       (conv): Conv2D(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (29): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0-1): 2 x BNSwishConv(
#           (bn_act): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           (conv_0): Conv2D(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (enc0): Sequential(
#     (0): ELU(alpha=1.0)
#     (1): Conv2D(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (2): ELU(alpha=1.0)
#   )
#   (enc_sampler): ModuleList(
#     (0-4): 5 x Conv2D(256, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5-14): 10 x Conv2D(128, 40, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
#   (dec_sampler): ModuleList(
#     (0-3): 4 x Sequential(
#       (0): ELU(alpha=1.0)
#       (1): Conv2D(256, 40, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (4-13): 10 x Sequential(
#       (0): ELU(alpha=1.0)
#       (1): Conv2D(128, 40, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (nf_cells): ModuleList()
#   (enc_kv): ModuleList()
#   (dec_kv): ModuleList()
#   (query): ModuleList()
#   (dec_tower): ModuleList(
#     (0): DecCombinerCell(
#       (conv): Conv2D(276, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (1): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(1536, 1536, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (2): DecCombinerCell(
#       (conv): Conv2D(276, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (3): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(1536, 1536, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4): DecCombinerCell(
#       (conv): Conv2D(276, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (5): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(1536, 1536, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (6): DecCombinerCell(
#       (conv): Conv2D(276, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (7): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(1536, 1536, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(1536, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=256, out_features=16, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=16, out_features=256, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (8): DecCombinerCell(
#       (conv): Conv2D(276, 256, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (9): Cell(
#       (skip): Sequential(
#         (0): UpSample()
#         (1): Conv2D(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(256, 1536, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(1536, 1536, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1536, bias=False)
#                 (1): BatchNorm2d(1536, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (4): Conv2D(1536, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (5): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (10): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (11): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (12): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (13): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (14): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (15): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (16): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (17): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (18): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (19): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (20): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (21): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (22): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (23): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (24): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (25): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (26): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (27): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (28): Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 768, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(768, 768, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=768, bias=False)
#                 (1): BatchNorm2d(768, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=128, out_features=8, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=8, out_features=128, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (29): DecCombinerCell(
#       (conv): Conv2D(148, 128, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (post_process): ModuleList(
#     (0): Cell(
#       (skip): Sequential(
#         (0): UpSample()
#         (1): Conv2D(128, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(128, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(384, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(384, 384, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=384, bias=False)
#                 (1): BatchNorm2d(384, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (4): Conv2D(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (5): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (1-2): 2 x Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(64, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(192, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(192, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=192, bias=False)
#                 (1): BatchNorm2d(192, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=64, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=64, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (3): Cell(
#       (skip): Sequential(
#         (0): UpSample()
#         (1): Conv2D(64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       )
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): UpsamplingNearest2d(scale_factor=2.0, mode='nearest')
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(64, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(192, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(192, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=192, bias=False)
#                 (1): BatchNorm2d(192, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (4): Conv2D(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (5): BatchNorm2d(32, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#     (4-5): 2 x Cell(
#       (skip): Identity()
#       (_ops): ModuleList(
#         (0): InvertedResidual(
#           (conv): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#             (1): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(32, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#                 (1): BatchNorm2d(96, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (2): ConvBNSwish(
#               (conv): Sequential(
#                 (0): Conv2D(96, 96, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=96, bias=False)
#                 (1): BatchNorm2d(96, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#                 (2): SiLU(inplace=True)
#               )
#             )
#             (3): Conv2D(96, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (4): BatchNorm2d(32, eps=1e-05, momentum=0.05, affine=True, track_running_stats=False)
#           )
#         )
#       )
#       (se): SE(
#         (se): Sequential(
#           (0): Linear(in_features=32, out_features=4, bias=True)
#           (1): ReLU(inplace=True)
#           (2): Linear(in_features=4, out_features=32, bias=True)
#           (3): Sigmoid()
#         )
#       )
#     )
#   )
#   (image_conditional): Sequential(
#     (0): ELU(alpha=1.0)
#     (1): Conv2D(32, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   )
# )

# %% [markdown]
# The NVAE consists of many convolutional layers which also explains the performance improvements when you run it on a GPU.

# %%
# number of convolutional layers
len(model.all_conv_layers)
# Out:
# 183

# %% [markdown]
# In total, the NVAE consists of almost 19 million parameters.

# %%
# number of parameters
nvae.count_parameters(model)
# Out:
# 18853518

# %% [markdown]
# ## Reconstructions
#
# We check how well the NVAE can reconstruct MNIST images. The model expects the MNIST data to be padded with two white pixels at the bottom, top, left, and right side. Moreover, the model is trained with a binarized version of the MNIST data that consists only of 0s and 1s instead of values between 0 and 1. If $\mathbf{x} = [\mathbf{x}_1 \cdots \mathbf{x}_{1024}]^\mathsf{T}$ denotes an image in the MNIST data set with padding, then a binarized version $\mathbf{y} = [\mathbf{y}_1 \cdots \mathbf{y}_{1024}]^\mathsf{T}$ is obtained by sampling entry $\mathbf{y}_i$ ($i = 1,\ldots,1024$) from a Bernoulli distribution with parameter $\mathbf{x}_i$, i.e.,
# \begin{equation*}
#     \mathbf{y}_i \sim \operatorname{Bern}(\mathbf{y}_i; \mathbf{x}_i).
# \end{equation*}

# %%
# preprocessing pipeline: add padding and sample binarized version
preprocess = transforms.Compose([
    transforms.Pad(2),
    lambda x: x.bernoulli(),
])

# %% [markdown]
# The decoder of the NVAE returns images that of size 32x32, consistent with the padding of the MNIST data. We crop the images when we compare them with the MNIST data without padding.

# %%
centercrop = transforms.CenterCrop(28)

# %% [markdown]
# To ensure that the computation is reasonably fast also if you do not use a GPU we limit ourselves to batches of 10 random images from the test data set in our analysis.

# %%
# download MNIST test data
testset = datasets.MNIST(root='./data', train=False, download=True, transform=transforms.ToTensor())

# define data loader
# if you use a GPU you can increase the batch size
# `pin_memory=True` is helpful when working with GPUs: https://pytorch.org/docs/stable/data.html#memory-pinning
testdata = torch.utils.data.DataLoader(
    testset, batch_size=10, shuffle=True, pin_memory=device.type=='cuda',
)

# %% [markdown]
# In the following code block we draw 10 random test images and compute their reconstructions, i.e., the output of the NVAE when running the encoder and the decoder.

# %%
with torch.no_grad(): # no gradients required
    # batch of 10 random images + labels from the test data set
    test_images, test_labels = next(iter(testdata))
    
    # move data to the GPU if available
    test_images = test_images.to(device)

    # compute reconstructions
    logits = model(preprocess(test_images))[0]
    test_reconstructions = centercrop(model.decoder_output(logits).mean)

# %% [markdown]
# We compare the original images and their reconstructions visually.

# %%
# plot a grid of random pairs of `originals` and `reconstructions`
def plot_reconstructions(originals, reconstructions, labels, nrows=4, ncols=2):
    # indices of displayed samples
    n = originals.shape[0]
    indices = np.random.choice(n, size=nrows*ncols, replace=False)

    fig, axes = plt.subplots(nrows=nrows, ncols=ncols, figsize=(10, 10))
    for (idx, ax) in zip(indices, axes.flat):
        # extract original, reconstruction, and label
        original = originals[idx]
        reconstruction = reconstructions[idx]
        label = labels[idx]

        # configure subplot
        ax.set_xticks(())
        ax.set_yticks(())
        ax.grid(False)
        ax.set_title(f"Label: {label.item()}", fontweight='bold')

        # plot original and reconstructed image in a grid
        grid = np.ones((32, 62))
        grid[2:30, 2:30] = original.squeeze().cpu().numpy()
        grid[2:30, 32:60] = reconstruction.squeeze().cpu().numpy()
        ax.imshow(grid, vmin=0.0, vmax=1.0, cmap='gray_r')

    return fig

# %%
plot_reconstructions(test_images, test_reconstructions, test_labels, nrows=5)
plt.show()

# %% [markdown]
# The reconstructions seem to be of much higher quality than the reconstructions from the simple VAE that we trained. This is not completely surprising though given the high complexity of the NVAE model.
#
# Again we also analyze the average squared reconstruction error
# \begin{equation*}
#     \mathrm{sqerr} := \frac{1}{10000} \sum_{i=1}^{10000} \|\mathbf{x}_i - \tilde{\mathbf{x}}_i\|^2_2
# \end{equation*}
# of the images $\mathbf{x}_i \in {[0,1]}^{784}$ and their reconstructions $\tilde{\mathbf{x}}_i \in \mathbb{R}^{784}$ ($i = 1,\ldots, 10000$) in the MNIST test data set as an objective measure for the quality of the reconstructions. To reduce the computation time, in particular when you do not use a GPU, we estimate it only from 10 batches of 10 random test images and do not evaluate the full test data set. If the estimation is reasonably fast you can increase the number of batches.

# %%
# only analyze 10 out of 1000 batches
# you can increase this if you use a GPU
nbatches = 10

sqerrors = []

with torch.no_grad(): # no gradients required
    for i, (images, _) in enumerate(testdata):
        # only analyze nbatches batches
        if i >= nbatches:
            break

        # show progress
        print("processing batch {:3d} ...".format(i + 1))
        
        # move data to GPU if available
        images = images.to(device)
    
        # compute reconstructions
        logits = model(preprocess(images))[0]
        reconstructions = centercrop(model.decoder_output(logits).mean)
        
        # compute average squared reconstruction error
        sqerror = (images - reconstructions).pow(2).view(-1, 784).sum(dim=1).mean()
        sqerrors.append(sqerror)

sqerr = torch.tensor(sqerrors).mean()
print(f"Average squared reconstruction error: {sqerr}")
# Out:
# processing batch   1 ...
# processing batch   2 ...
# processing batch   3 ...
# processing batch   4 ...
# processing batch   5 ...
# processing batch   6 ...
# processing batch   7 ...
# processing batch   8 ...
# processing batch   9 ...
# processing batch  10 ...
# Average squared reconstruction error: 7.447307586669922

# %% [markdown]
# ## Generating images
#
# Of course, we can also generate new images from the NVAE. Here we sample one image from the NVAE with temperature `T` and display it.

# %%
# sample a single image with temperature `T`
T = 0.6

with torch.no_grad(): # no gradients required
    # compute decoding distribution
    logits = model.sample(1, T) 
    output = model.decoder_output(logits)
    
    # use non-binarized sample for MNIST, otherwise sample from the decoding distribution
    output_img = output.mean if isinstance(output, torch.distributions.bernoulli.Bernoulli) else output.sample()
    
    # reorder the axes as (nsamples, channels, height, width)
    output_img = output_img.permute(0, 2, 3, 1).squeeze().cpu().numpy()

    # crop MNIST images
    if model.dataset == 'mnist':
        output_img = output_img[2:30, 2:30]

# plot sample
plt.xticks([])
plt.yticks([])
if model.dataset == 'mnist':
    # plot MNIST images as grayscale images
    plt.imshow(output_img, vmin=0.0, vmax=1.0, cmap='gray_r')
else:
    plt.imshow(output_img)
plt.show()

# %% [markdown]
# ### Task
#
# Play around with the notebook. Some suggestions:
# - Change the temperature and study how it affects the quality of the generated image.
# - Generate images from pretrained NVAEs for other image data sets (you can not analyze the reconstructions since we did not load these other data sets).
#
# **Warning: The files with pretrained parameters for other data sets are large (> 1.5GB). You might have to delete some files with pretrained parameters in the file browser on Google Colab to free up space. Since the NVAEs for other image data sets are also more complex (e.g., more convolutional layers) it takes more time to run them, in particular if you do not use a GPU.**

# %%
# load pretrained NVAE
# possible data sets:
# "mnist", "celeba_64", "celeba_256a", "celeba_256b", "cifar10a", "cifar10b", "ffhq"
model = nvae.load_pretrained_model("celeba_256a")

# move model to the GPU if available
model = model.to(device)
# Out:
# downloading checkpoint of pretrained model for celeba_256a ...
# len log norm: 986
# len bn: 460

# %%
# sample a single image with temperature `T`
T = 0.6

with torch.no_grad(): # no gradients required
    # compute decoding distribution
    logits = model.sample(1, T) 
    output = model.decoder_output(logits)
    
    # use non-binarized sample for MNIST, otherwise sample from the decoding distribution
    output_img = output.mean if isinstance(output, torch.distributions.bernoulli.Bernoulli) else output.sample()
    
    # reorder the axes as (nsamples, channels, height, width)
    output_img = output_img.permute(0, 2, 3, 1).squeeze().cpu().numpy()

    # crop MNIST images
    if model.dataset == 'mnist':
        output_img = output_img[2:30, 2:30]

# plot sample
plt.xticks([])
plt.yticks([])
if model.dataset == 'mnist':
    # plot MNIST images as grayscale images
    plt.imshow(output_img, vmin=0.0, vmax=1.0, cmap='gray_r')
else:
    plt.imshow(output_img)
plt.show()
